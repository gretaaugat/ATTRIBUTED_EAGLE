# %%
import networkx as nx
import pandas as pd
import numpy as np
from dtaidistance.dtw import distance_matrix, distance
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw
import picos as pic
import itertools as it
import copy
import json

# %%
def graph_feat(N,feature,feature_col,file_matrix,file_co2):

    adj = pd.read_csv(file_matrix,index_col=0)
    adj.index = adj.index.map(str)
    
    def build_graph(adj,nn_radi):
        names = adj.index
        G = nx.Graph()
        tmp = np.array(adj)
        tmp = np.argsort(tmp)
        tmp = np.argwhere(tmp < nn_radi)
        for e in tmp:
            G.add_edge(names[e[0]],names[e[1]])
        return(G)

    # Build KNN Graph
    
    G = [build_graph(adj,i) for i in range(1,N)]
    
    feature.index = feature.index.map(str)

    for gg in G:
        attrs={}

        for edge in gg.edges():
            attrs[(edge[0],edge[1])] = {}

            for v in feature.columns[feature_col:]:

                #To use difference instead of average on the edge use the command line below
                #w = np.abs(feature[v][edge[0]] - feature[v][edge[1]]) 
                w = np.mean([feature[v][edge[0]] , feature[v][edge[1]]])       
                attrs[(edge[0],edge[1])][v] = w
        
        nx.set_edge_attributes(gg, attrs)
    
    co2 = pd.read_csv(file_co2,index_col=0)
    co2.index = co2.index.map(str)
    
    for gg in G:
        attrs={}

        for edge in gg.edges():
            try:
                b0 = co2['2010'][edge[0]]
                b1 = co2['2010'][edge[1]]

                attrs[(edge[0],edge[1])] = {'co2' : np.mean([b0,b1])}
                                           
            except:
                pass

        nx.set_edge_attributes(gg, attrs)

    
    ### I.Preprocessing Phase: Computations over the Domain

    K = len(G)

    #Amount of features
    F = len(feature.columns[feature_col:])

    def feat_edge(D,x):
        data_2 = [v for _,_,v in D.edges.data(x)]
        data_2_at = [v for v in data_2 if v is not None]
        d2 = np.histogram(data_2_at,bins=5)[0]
        #fixed the number of bins, not using scott anymore
        #d2 = np.histogram(data_2_at,bins=5)[0]
        return(d2/float(sum(d2)))

    ### Step 1: Feature Representation Model

    PDF_e = [[feat_edge(gg,v) for v in feature.columns[feature_col:]] for gg in G]
    
    ### Step 2: Feature Diversity Model

    dists_e = [distance_matrix(PDF_e[i]) for i in range(K)]
    
    #Edge
    SF_e = np.nan_to_num(np.mean(dists_e,axis=0),posinf=0)
    
    
    ### II. Query Phase: Summary Creation

    ### Step 1: Domain-specificity Model
    
    PDF_ge = [feat_edge(gg,'co2') for gg in G]
    
    diff_e = [[distance(PDF_ge[i],PDF_e[i][l]) for l in range(F)] for i in range(K)]

    h_e= np.mean(diff_e,axis=0)
                                                                                 
    ### Step 2: Feature Selection

    #Regularization Parameters l1,l2, l3

    l1 = 1/F
    l2 = 1
    l3 = 1

    #Identity Matrix: np.identity(F)

    Q_e = np.multiply(SF_e,l1) + np.multiply(np.identity(F),l2)
    r_e = np.multiply(h_e,l3)

    sel_feat = 3

    #Solver Edge
    prob_e = pic.Problem()
    K=F

    f = pic.RealVariable('f',K)
    prob_e.add_constraint(pic.sum(f.T)<=F)
    prob_e.add_constraint(pic.sum(f.T)>=sel_feat)
    prob_e.set_objective('min',f.T*Q_e*f+f.T*r_e)
    sol_e = prob_e.solve(solver="ecos",primals=None,duals=None,max_footprints=100,verbosity=0,rel_prim_fsb_tol=1e-3,rel_dual_fsb_tol=1e-3,abs_prim_fsb_tol=1e-3,abs_dual_fsb_tol=1e-3)

    values = np.array(list(sol_e.primals.values())[0])
    
    order = np.argsort(-values)

    result_order = list(zip(feature.columns[feature_col:][order],values[order]))
    
    features_order = list(feature.columns[feature_col:][order])
    
    y = np.round(list(sol_e.primals.values()))
    result = np.where(y == 1)
    
    return(features_order,result_order, result)

# %%
#N = number of neighbors - 1 up to 20
N=2
#Municipality Code Column (features are considered from this column)
feature_col = 0
feature = pd.read_csv("data/Brasil_new/br_data_census_2010.csv", index_col=feature_col)
features_order,result_order, result = graph_feat(N,feature,feature_col,"data/Brasil_new/filtered_adjacency_matrix_inv.csv","data/co2/br_co2_log_2010.csv")

# %%
df = pd.DataFrame.from_dict({ 'Order' : result_order
                  }, orient='index').transpose()

# %%
df.head(10)
# Out:
#                                          Order
# 0  (CENSUS_Pessoa02_V176, 0.30342378004252646)
# 1  (CENSUS_Pessoa13_V060, 0.30145462633661063)
# 2  (CENSUS_Pessoa12_V063, 0.30086605033948877)
# 3   (CENSUS_Pessoa13_V058, 0.2977004765802157)
# 4   (CENSUS_Pessoa12_V054, 0.2969294733442613)
# 5  (CENSUS_Pessoa11_V053, 0.29602453403028445)
# 6  (CENSUS_Pessoa02_V174, 0.29576867234815524)
# 7  (CENSUS_Pessoa01_V022, 0.29571192785010175)
# 8   (CENSUS_Pessoa12_V066, 0.2954870422977112)
# 9    (CENSUS_Pessoa02_V177, 0.293637387169904)

# %%
#Number of features determined by the CFS algorithm in https://github.com/tpinhoda/EF-FS_Pipeline
data_json = {'selected_features':features_order[0:265]}

data_json
# Out:
# {'selected_features': ['CENSUS_Pessoa02_V176',
#   'CENSUS_Pessoa13_V060',
#   'CENSUS_Pessoa12_V063',
#   'CENSUS_Pessoa13_V058',
#   'CENSUS_Pessoa12_V054',
#   'CENSUS_Pessoa11_V053',
#   'CENSUS_Pessoa02_V174',
#   'CENSUS_Pessoa01_V022',
#   'CENSUS_Pessoa12_V066',
#   'CENSUS_Pessoa02_V177',
#   'CENSUS_Responsavel02_V029',
#   'CENSUS_Pessoa02_V194',
#   'CENSUS_Responsavel02_V034',
#   'CENSUS_Pessoa02_V178',
#   'CENSUS_Pessoa12_V069',
#   'CENSUS_Pessoa08_V112',
#   'CENSUS_Pessoa01_V021',
#   'CENSUS_Pessoa02_V091',
#   'CENSUS_Pessoa06_V020',
#   'CENSUS_Responsavel02_V035',
#   'CENSUS_Pessoa02_V186',
#   'CENSUS_Pessoa08_V116',
#   'CENSUS_Pessoa12_V057',
#   'CENSUS_Pessoa01_V006',
#   'CENSUS_Pessoa12_V067',
#   'CENSUS_Pessoa02_V102',
#   'CENSUS_Pessoa08_V124',
#   'CENSUS_Pessoa01_V015',
#   'CENSUS_Pessoa11_V048',
#   'CENSUS_Responsavel02_V132',
#   'CENSUS_Pessoa07_V069',
#   'CENSUS_ResponsavelRenda_V065',
#   'CENSUS_ResponsavelRenda_V131',
#   'CENSUS_Pessoa02_V198',
#   'CENSUS_Responsavel02_V026',
#   'CENSUS_Pessoa07_V071',
#   'CENSUS_Pessoa01_V019',
#   'CENSUS_Pessoa02_V179',
#   'CENSUS_Pessoa02_V201',
#   'CENSUS_Pessoa02_V190',
#   'CENSUS_Pessoa13_V075',
#   'CENSUS_Pessoa12_V065',
#   'CENSUS_Pessoa02_V101',
#   'CENSUS_Responsavel02_V023',
#   'CENSUS_Pessoa08_V125',
#   'CENSUS_Pessoa02_V202',
#   'CENSUS_Pessoa06_V019',
#   'CENSUS_Pessoa12_V060',
#   'CENSUS_Pessoa11_V074',
#   'CENSUS_Pessoa02_V175',
#   'CENSUS_Pessoa11_V047',
#   'CENSUS_PessoaRenda_V065',
#   'CENSUS_Pessoa01_V007',
#   'CENSUS_Pessoa11_V052',
#   'CENSUS_PessoaRenda_V131',
#   'CENSUS_Pessoa12_V062',
#   'CENSUS_Pessoa08_V120',
#   'CENSUS_Pessoa02_V187',
#   'CENSUS_Pessoa08_V113',
#   'CENSUS_Pessoa12_V053',
#   'CENSUS_Pessoa13_V055',
#   'CENSUS_Pessoa01_V023',
#   'CENSUS_Domicilio01_V077',
#   'CENSUS_Pessoa02_V193',
#   'CENSUS_Responsavel02_V131',
#   'CENSUS_Pessoa08_V122',
#   'CENSUS_Pessoa02_V089',
#   'CENSUS_Pessoa08_V118',
#   'CENSUS_Pessoa01_V009',
#   'CENSUS_Pessoa02_V207',
#   'CENSUS_Pessoa02_V096',
#   'CENSUS_Pessoa06_V013',
#   'CENSUS_Pessoa12_V046',
#   'CENSUS_Pessoa12_V073',
#   'CENSUS_ResponsavelRenda_V064',
#   'CENSUS_Pessoa12_V003',
#   'CENSUS_Pessoa13_V066',
#   'CENSUS_PessoaRenda_V112',
#   'CENSUS_ResponsavelRenda_V130',
#   'CENSUS_Pessoa13_V069',
#   'CENSUS_Pessoa01_V016',
#   'CENSUS_Pessoa12_V045',
#   'CENSUS_Pessoa13_V052',
#   'CENSUS_Pessoa13_V074',
#   'CENSUS_Responsavel02_V024',
#   'CENSUS_Pessoa12_V055',
#   'CENSUS_Responsavel01_V001',
#   'CENSUS_Pessoa12_V044',
#   'CENSUS_PessoaRenda_V046',
#   'CENSUS_Pessoa07_V024',
#   'CENSUS_Pessoa02_V094',
#   'CENSUS_Pessoa13_V076',
#   'CENSUS_Pessoa02_V093',
#   'CENSUS_Pessoa13_V056',
#   'CENSUS_Pessoa13_V067',
#   'CENSUS_Domicilio01_V063',
#   'CENSUS_Pessoa12_V072',
#   'CENSUS_Pessoa07_V073',
#   'CENSUS_Pessoa02_V180',
#   'CENSUS_Pessoa06_V168',
#   'CENSUS_Pessoa07_V167',
#   'CENSUS_Pessoa12_V070',
#   'CENSUS_Pessoa06_V024',
#   'CENSUS_Pessoa11_V054',
#   'CENSUS_Pessoa13_V061',
#   'CENSUS_Pessoa13_V068',
#   'CENSUS_Pessoa02_V165',
#   'CENSUS_Pessoa13_V059',
#   'CENSUS_Pessoa13_V062',
#   'CENSUS_Domicilio01_V060',
#   'CENSUS_Pessoa02_V196',
#   'CENSUS_Pessoa02_V185',
#   'CENSUS_Pessoa12_V076',
#   'CENSUS_Responsavel02_V025',
#   'CENSUS_Pessoa08_V123',
#   'CENSUS_ResponsavelRenda_V112',
#   'CENSUS_Pessoa01_V029',
#   'CENSUS_ResponsavelRenda_V046',
#   'CENSUS_Pessoa12_V071',
#   'CENSUS_Pessoa02_V100',
#   'CENSUS_Pessoa02_V188',
#   'CENSUS_Pessoa12_V047',
#   'CENSUS_Pessoa13_V026',
#   'CENSUS_Pessoa01_V004',
#   'CENSUS_Pessoa06_V015',
#   'CENSUS_Pessoa12_V064',
#   'CENSUS_Pessoa02_V090',
#   'CENSUS_Pessoa02_V120',
#   'CENSUS_Domicilio01_V095',
#   'CENSUS_Pessoa11_V071',
#   'CENSUS_Pessoa12_V043',
#   'CENSUS_Pessoa12_V061',
#   'CENSUS_Pessoa12_V075',
#   'CENSUS_Pessoa06_V026',
#   'CENSUS_Pessoa01_V011',
#   'CENSUS_Pessoa12_V052',
#   'CENSUS_Pessoa13_V078',
#   'CENSUS_Domicilio01_V050',
#   'CENSUS_Pessoa08_V119',
#   'CENSUS_Pessoa12_V059',
#   'CENSUS_Pessoa06_V155',
#   'CENSUS_Pessoa13_V081',
#   'CENSUS_Pessoa11_V003',
#   'CENSUS_Responsavel02_V109',
#   'CENSUS_ResponsavelRenda_V042',
#   'CENSUS_Pessoa01_V080',
#   'CENSUS_Pessoa08_V114',
#   'CENSUS_ResponsavelRenda_V108',
#   'CENSUS_Pessoa02_V092',
#   'CENSUS_Responsavel02_V018',
#   'CENSUS_Pessoa01_V010',
#   'CENSUS_PessoaRenda_V010',
#   'CENSUS_Pessoa13_V048',
#   'CENSUS_Responsavel02_V031',
#   'CENSUS_Pessoa02_V095',
#   'CENSUS_Pessoa07_V072',
#   'CENSUS_Pessoa08_V168',
#   'CENSUS_Pessoa12_V080',
#   'CENSUS_Pessoa06_V058',
#   'CENSUS_Pessoa06_V056',
#   'CENSUS_Pessoa12_V078',
#   'CENSUS_Pessoa13_V092',
#   'CENSUS_Pessoa01_V018',
#   'CENSUS_Responsavel02_V161',
#   'CENSUS_PessoaRenda_V076',
#   'CENSUS_Responsavel01_V066',
#   'CENSUS_Responsavel02_V203',
#   'CENSUS_Domicilio01_V094',
#   'CENSUS_Pessoa11_V106',
#   'CENSUS_Responsavel02_V177',
#   'CENSUS_Pessoa11_V068',
#   'CENSUS_Pessoa01_V008',
#   'CENSUS_Pessoa12_V095',
#   'CENSUS_Responsavel01_V053',
#   'CENSUS_Pessoa07_V031',
#   'CENSUS_Pessoa02_V172',
#   'CENSUS_Pessoa07_V056',
#   'CENSUS_Responsavel02_V175',
#   'CENSUS_Responsavel02_V165',
#   'CENSUS_PessoaRenda_V021',
#   'CENSUS_Pessoa13_V113',
#   'CENSUS_Pessoa13_V108',
#   'CENSUS_Pessoa12_V096',
#   'CENSUS_Pessoa02_V195',
#   'CENSUS_Pessoa06_V166',
#   'CENSUS_Responsavel02_V072',
#   'CENSUS_Responsavel01_V031',
#   'CENSUS_Pessoa06_V156',
#   'CENSUS_Pessoa12_V112',
#   'CENSUS_Pessoa11_V109',
#   'CENSUS_PessoaRenda_V087',
#   'CENSUS_Responsavel02_V064',
#   'CENSUS_Responsavel02_V173',
#   'CENSUS_Responsavel02_V156',
#   'CENSUS_Responsavel02_V158',
#   'CENSUS_Responsavel01_V058',
#   'CENSUS_Responsavel02_V166',
#   'CENSUS_Pessoa02_V199',
#   'CENSUS_Pessoa02_V205',
#   'CENSUS_Pessoa11_V051',
#   'CENSUS_Pessoa11_V025',
#   'CENSUS_Pessoa13_V037',
#   'CENSUS_Pessoa08_V160',
#   'CENSUS_Domicilio01_V089',
#   'CENSUS_Pessoa09_V002',
#   'CENSUS_Domicilio01_V081',
#   'CENSUS_Responsavel02_V065',
#   'CENSUS_Pessoa08_V162',
#   'CENSUS_Pessoa07_V184',
#   'CENSUS_Pessoa07_V035',
#   'CENSUS_Responsavel02_V164',
#   'CENSUS_Responsavel01_V041',
#   'CENSUS_Pessoa13_V119',
#   'CENSUS_Responsavel01_V020',
#   'CENSUS_Pessoa07_V161',
#   'CENSUS_Domicilio01_V090',
#   'CENSUS_Pessoa12_V013',
#   'CENSUS_Responsavel02_V159',
#   'CENSUS_Responsavel02_V070',
#   'CENSUS_Pessoa06_V054',
#   'CENSUS_Responsavel02_V013',
#   'CENSUS_Pessoa11_V103',
#   'CENSUS_Pessoa07_V114',
#   'CENSUS_Pessoa06_V173',
#   'CENSUS_Pessoa11_V091',
#   'CENSUS_Pessoa01_V028',
#   'CENSUS_Pessoa13_V072',
#   'CENSUS_Responsavel01_V022',
#   'CENSUS_Pessoa12_V093',
#   'CENSUS_Pessoa11_V111',
#   'CENSUS_Pessoa11_V027',
#   'CENSUS_Pessoa01_V026',
#   'CENSUS_Pessoa12_V089',
#   'CENSUS_Pessoa13_V022',
#   'CENSUS_Pessoa11_V006',
#   'CENSUS_Pessoa02_V249',
#   'CENSUS_Pessoa13_V111',
#   'CENSUS_Pessoa07_V055',
#   'CENSUS_Pessoa11_V110',
#   'CENSUS_Pessoa06_V191',
#   'CENSUS_Pessoa11_V100',
#   'CENSUS_Pessoa13_V057',
#   'CENSUS_Responsavel01_V065',
#   'CENSUS_Pessoa02_V203',
#   'CENSUS_Pessoa08_V161',
#   'CENSUS_Pessoa13_V034',
#   'CENSUS_Pessoa06_V193',
#   'CENSUS_Pessoa07_V187',
#   'CENSUS_Domicilio01_V082',
#   'CENSUS_Pessoa12_V025',
#   'CENSUS_Responsavel02_V147',
#   'CENSUS_Pessoa06_V057',
#   'CENSUS_Pessoa07_V005',
#   'CENSUS_Responsavel01_V057',
#   'CENSUS_Pessoa01_V020',
#   'CENSUS_Pessoa06_V183',
#   'CENSUS_Pessoa01_V033',
#   'CENSUS_Pessoa06_V051',
#   'CENSUS_Pessoa12_V024',
#   'CENSUS_Pessoa13_V098',
#   'CENSUS_Pessoa11_V013',
#   'CENSUS_Responsavel02_V053',
#   'CENSUS_Pessoa06_V182',
#   'CENSUS_Pessoa09_V004',
#   'CENSUS_Responsavel02_V170']}

# %%
def escrever_json(lista):
    with open('features_selected/attributed_eagle_log_co2_n2.json', 'w') as f:
        json.dump(lista, f, indent=4)
    
escrever_json(data_json)
