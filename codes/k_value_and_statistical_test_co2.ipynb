# %%
# !pip install baycomp
# Out:
# Requirement already satisfied: baycomp in /Users/greta/anaconda3/lib/python3.7/site-packages (1.0.3)
# Requirement already satisfied: numpy>=1.13.1 in /Users/greta/anaconda3/lib/python3.7/site-packages (from baycomp) (1.21.5)
# Requirement already satisfied: scipy>=0.19.1 in /Users/greta/anaconda3/lib/python3.7/site-packages (from baycomp) (1.7.3)
# Requirement already satisfied: matplotlib>=2.1.2 in /Users/greta/anaconda3/lib/python3.7/site-packages (from baycomp) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /Users/greta/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.1.2->baycomp) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/greta/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.1.2->baycomp) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/greta/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.1.2->baycomp) (1.4.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/greta/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.1.2->baycomp) (3.1.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/greta/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.1.2->baycomp) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/greta/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.1.2->baycomp) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/greta/anaconda3/lib/python3.7/site-packages (from matplotlib>=2.1.2->baycomp) (4.38.0)
# Requirement already satisfied: typing-extensions in /Users/greta/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.1.2->baycomp) (4.7.1)
# Requirement already satisfied: six>=1.5 in /Users/greta/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.2->baycomp) (1.16.0)

# %%
import pandas as pd
from baycomp import SignedRankTest
import glob

# %%
files = glob.glob('../pipeline/results_co2/*/by_folds/*')

# %%
results = {}
for file in files:
    splits = file.split('/')  
    
    if splits[3] not in results:
        results[splits[3]] = {}
    
    results[splits[3]][splits[5]] = pd.read_csv(file)
    
    results[splits[3]][splits[5]]['k'] = int(splits[3].split('_')[1])

# %%
knns = list(results.keys())

# %%
models = list(results[knns[0]].keys())

# %%
combinado = {}
for model in models:
    combinado[model] = pd.concat([results[k][model] for k in knns])

# %%
methods = {
    'cfs.csv'      : "CFS" , 
    'rrelieff.csv' : "RELIEFF", 
    'rf.csv'       : "RF",
    'rfe.csv'      : "RFE",
}

# %%
rename_mapping = {
    "cfs.csv": "CFS",
    "rrelieff.csv": "RRELIEFF",
    "rf.csv": "RANDOM_FOREST",
    "attributed_eagle_log_co2_n2.csv": "ATTRIBUTED_EAGLE",
    "rfe.csv": "RFE"
}

colors = {
    "ATTRIBUTED_EAGLE": "blue",
    "CFS": "green",
    "RRELIEFF": "purple",
    "RANDOM_FOREST": "red",
    "RFE": "orange"
}

k_values = [10, 20, 30, 40, 50, 60]

for measure in ['sae', 'rmse']:
    tmp = pd.DataFrame({model:combinado[model].groupby('k')[measure].mean() for model in combinado.keys()})
    rope = max(0.02,tmp.std().mean())

    tmp.columns = ["ATTRIBUTED_EAGLE", "CFS", "RRELIEFF", "RANDOM_FOREST", "RFE"]

    tmp_filtered = tmp.loc[k_values]

    plot_title = f"CO2 Prediction - Comparing Feature Selection ({measure.upper()})"

    plot = tmp_filtered.plot(kind='line', title=plot_title, ylabel=measure.upper(), color=[colors[col] for col in tmp_filtered.columns])

    plot.set_xticks(k_values)
    plot.set_xticklabels([str(k) for k in k_values]) 

    fig = plot.get_figure()
    fig.savefig("./images/co2_"+measure+".pdf")

    for k, v in methods.items():
        fig = SignedRankTest.plot(-combinado['attributed_eagle_log_co2_n2.csv'][measure],
                                  -combinado[k][measure], rope=rope, names=["ATTRIBUTED_EAGLE",v])
        fig.savefig("./images/co2_eagle_"+v.lower()+"_"+measure+".pdf")
